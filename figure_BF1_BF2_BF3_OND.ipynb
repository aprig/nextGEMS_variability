# %%
# Author: Arthur Prigent
# Email: aprigent@ictp.it

# %%
import Atools as Atools
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import cmocean.cm as cmo
from scipy import stats
from datetime import datetime
import cartopy.crs as ccrs
import cartopy
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import matplotlib.ticker as mticker
import matplotlib.patches as mpatches
from matplotlib import gridspec

# %%
def plot_regress_map_bf1(ax,ssta_detrended_std,levels,cmap):
    ftz=15
    
    p0=ax.contourf(ssta_detrended_std.lon,ssta_detrended_std.lat,ssta_detrended_std.alpha*100,
                      cmap=cmap,transform=ccrs.PlateCarree(),levels=levels,extend='both')
    #ax.add_patch(mpatches.Rectangle(xy=[-20, -3], width=20, height=6,edgecolor='blue',fill=None,
    #                                    alpha=1,linewidth=3,label='ATL3'))
    c1b = ax.contourf(ssta_detrended_std.lon,ssta_detrended_std.lat,
                      ssta_detrended_std.pval,[np.min(ssta_detrended_std.pval),0.05,np.max(ssta_detrended_std.pval)],
                      zorder=2,
                          hatches=['.', None],colors="none", transform=ccrs.PlateCarree())
    CS = ax.contour(ssta_detrended_std.lon,ssta_detrended_std.lat,ssta_detrended_std.rval**2,
                      colors='black',transform=ccrs.PlateCarree(),levels=[0.4,0.6,0.8])
    ax.clabel(CS, inline=1, fontsize=10,zorder=2)
    gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=1, color='black', alpha=0.8, linestyle='-',zorder=3)
    gl.xlabels_top = False
    gl.ylabels_right = False
    gl.xlabel_style = {'size': ftz, 'color': 'black'}
    gl.ylabel_style = {'size': ftz, 'color': 'black'}
    gl.xlocator = mticker.FixedLocator([-40,-20, 0,20])
    gl.ylocator = mticker.FixedLocator([-20,-10, 0,10,20])
    ax.add_feature(cartopy.feature.LAND, edgecolor='black',color='lightgrey',zorder=2)
    #ax0.add_feature(cartopy.feature.BORDERS,zorder=2)# adds national borders
    ax.add_feature(cartopy.feature.COASTLINE,zorder=2)# add coastlines
    #ax[i].add_feature(cartopy.feature.RIVERS,zorder=2)# add rivers
    #ax.set_title(ssta_detrended_std.model.values,fontsize=ftz)
    return p0




def plot_regress_map_bf2(ax,ssta_detrended_std,levels,cmap):
    ftz=15
    
    p0=ax.contourf(ssta_detrended_std.lon,ssta_detrended_std.lat,ssta_detrended_std.alpha,
                      cmap=cmap,transform=ccrs.PlateCarree(),levels=levels,extend='both')
    #ax.add_patch(mpatches.Rectangle(xy=[-20, -3], width=20, height=6,edgecolor='blue',fill=None,
    #                                    alpha=1,linewidth=3,label='ATL3'))
    c1b = ax.contourf(ssta_detrended_std.lon,ssta_detrended_std.lat,
                      ssta_detrended_std.pval,[np.min(ssta_detrended_std.pval),0.05,np.max(ssta_detrended_std.pval)],
                      zorder=2,
                          hatches=['.', None],colors="none", transform=ccrs.PlateCarree())
    CS = ax.contour(ssta_detrended_std.lon,ssta_detrended_std.lat,ssta_detrended_std.rval**2,
                      colors='black',transform=ccrs.PlateCarree(),levels=[0.4,0.6,0.8])
    ax.clabel(CS, inline=1, fontsize=10,zorder=2)
    gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=1, color='black', alpha=0.8, linestyle='-',zorder=3)
    gl.xlabels_top = False
    gl.ylabels_right = False
    gl.xlabel_style = {'size': ftz, 'color': 'black'}
    gl.ylabel_style = {'size': ftz, 'color': 'black'}
    gl.xlocator = mticker.FixedLocator([-40,-20, 0,20])
    gl.ylocator = mticker.FixedLocator([-20,-10, 0,10,20])
    ax.add_feature(cartopy.feature.LAND, edgecolor='black',color='lightgrey',zorder=2)
    #ax0.add_feature(cartopy.feature.BORDERS,zorder=2)# adds national borders
    ax.add_feature(cartopy.feature.COASTLINE,zorder=2)# add coastlines
    #ax[i].add_feature(cartopy.feature.RIVERS,zorder=2)# add rivers
    #ax.set_title(ssta_detrended_std.model.values,fontsize=ftz)
    return p0




def plot_regress_map_bf3(ax,ssta_detrended_std,levels,cmap):
    ftz=15
    
    p0=ax.contourf(ssta_detrended_std.lon,ssta_detrended_std.lat,ssta_detrended_std.alpha,
                      cmap=cmap,transform=ccrs.PlateCarree(),levels=levels,extend='both')
    #ax.add_patch(mpatches.Rectangle(xy=[-20, -3], width=20, height=6,edgecolor='blue',fill=None,
    #                                    alpha=1,linewidth=3,label='ATL3'))
    c1b = ax.contourf(ssta_detrended_std.lon,ssta_detrended_std.lat,
                      ssta_detrended_std.pval,[np.min(ssta_detrended_std.pval),0.05,np.max(ssta_detrended_std.pval)],
                      zorder=2,
                          hatches=['.', None],colors="none", transform=ccrs.PlateCarree())
    CS = ax.contour(ssta_detrended_std.lon,ssta_detrended_std.lat,ssta_detrended_std.rval**2,
                      colors='black',transform=ccrs.PlateCarree(),levels=[0.4,0.6,0.8])
    ax.clabel(CS, inline=1, fontsize=10,zorder=2)
    gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=1, color='black', alpha=0.8, linestyle='-',zorder=3)
    gl.xlabels_top = False
    gl.ylabels_right = False
    gl.xlabel_style = {'size': ftz, 'color': 'black'}
    gl.ylabel_style = {'size': ftz, 'color': 'black'}
    gl.xlocator = mticker.FixedLocator([-40,-20, 0,20])
    gl.ylocator = mticker.FixedLocator([-20,-10, 0,10,20])
    ax.add_feature(cartopy.feature.LAND, edgecolor='black',color='lightgrey',zorder=2)
    #ax0.add_feature(cartopy.feature.BORDERS,zorder=2)# adds national borders
    ax.add_feature(cartopy.feature.COASTLINE,zorder=2)# add coastlines
    #ax[i].add_feature(cartopy.feature.RIVERS,zorder=2)# add rivers
    #ax.set_title(ssta_detrended_std.model.values,fontsize=ftz)
    return p0



def plot_regress_map_td(ax,ssta_detrended_std,levels,cmap):
    ftz=15
    
    p0=ax.contourf(ssta_detrended_std.lon,ssta_detrended_std.lat,ssta_detrended_std.alpha,
                      cmap=cmap,transform=ccrs.PlateCarree(),levels=levels,extend='both')
    #ax.add_patch(mpatches.Rectangle(xy=[-20, -3], width=20, height=6,edgecolor='blue',fill=None,
    #                                    alpha=1,linewidth=3,label='ATL3'))
    c1b = ax.contourf(ssta_detrended_std.lon,ssta_detrended_std.lat,
                      ssta_detrended_std.pval,[np.min(ssta_detrended_std.pval),0.05,np.max(ssta_detrended_std.pval)],
                      zorder=2,
                          hatches=['.', None],colors="none", transform=ccrs.PlateCarree())
    CS = ax.contour(ssta_detrended_std.lon,ssta_detrended_std.lat,ssta_detrended_std.rval**2,
                      colors='black',transform=ccrs.PlateCarree(),levels=[0.4,0.6,0.8])
    ax.clabel(CS, inline=1, fontsize=10,zorder=2)
    gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=1, color='black', alpha=0.8, linestyle='-',zorder=3)
    gl.xlabels_top = False
    gl.ylabels_right = False
    gl.xlabel_style = {'size': ftz, 'color': 'black'}
    gl.ylabel_style = {'size': ftz, 'color': 'black'}
    gl.xlocator = mticker.FixedLocator([-40,-20, 0,20])
    gl.ylocator = mticker.FixedLocator([-20,-10, 0,10,20])
    ax.add_feature(cartopy.feature.LAND, edgecolor='black',color='lightgrey',zorder=2)
    #ax0.add_feature(cartopy.feature.BORDERS,zorder=2)# adds national borders
    ax.add_feature(cartopy.feature.COASTLINE,zorder=2)# add coastlines
    #ax[i].add_feature(cartopy.feature.RIVERS,zorder=2)# add rivers
    #ax.set_title(ssta_detrended_std.model.values,fontsize=ftz)
    return p0


dir_data1 = '/work/bb1153/b381638/ICON/ngc2013/'
dir_data2 = '/work/bb1153/b381638/ICON/rthk001/'

dir_ind = '/work/bb1153/b381602/ICON/indices/'
dir_ind2 = '/work/bb1153/b381602/ICON/'

# %% [markdown]
# # Load BFs
# Depends on :
# - b382431/prepare_BF1_map_atl.ipynb
# - b382431/prepare_BF2_map_atl.ipynb
# - b382431/prepare_BF3_map_atl.ipynb

# %%
bf1_1 = xr.open_dataset('data/bf1_thin_ond.nc')
bf1_2 = xr.open_dataset('data/bf1_thick_ond.nc')


bf2_1 = xr.open_dataset('data/bf2_thin_son.nc')
bf2_2 = xr.open_dataset('data/bf2_thick_son.nc')


bf3_1 = xr.open_dataset('data/bf3_thin_ond.nc')
bf3_2 = xr.open_dataset('data/bf3_thick_ond.nc')



nhfa_ssta_1 = xr.open_dataset('data/net_heat_flux_damping_1_ond.nc')
nhfa_ssta_2 = xr.open_dataset('data/net_heat_flux_damping_2_ond.nc')

# %% [markdown]
# # figure BFs

# %%
ftz=15


fig = plt.figure(figsize=[15, 20])
fig.patch.set_facecolor('white')
gs = gridspec.GridSpec(4, 2)



ax0  = fig.add_subplot(gs[0, 0],projection=ccrs.PlateCarree())
ax1  = fig.add_subplot(gs[0, 1],projection=ccrs.PlateCarree())


ax2  = fig.add_subplot(gs[1, 0],projection=ccrs.PlateCarree())
ax3  = fig.add_subplot(gs[1, 1],projection=ccrs.PlateCarree())


ax4  = fig.add_subplot(gs[2, 0],projection=ccrs.PlateCarree())
ax5  = fig.add_subplot(gs[2, 1],projection=ccrs.PlateCarree())


ax6  = fig.add_subplot(gs[3, 0],projection=ccrs.PlateCarree())
ax7  = fig.add_subplot(gs[3, 1],projection=ccrs.PlateCarree())





cax0 = inset_axes(ax0,
                   width="230%",  # width = 5% of parent_bbox width
                   height="5%",  # height : 50%
                   loc='lower left',
                   bbox_to_anchor=(0, -0.15, 1, 1),
                   bbox_transform=ax0.transAxes,
                   borderpad=0,
                   )

cax2 = inset_axes(ax2,
                   width="230%",  # width = 5% of parent_bbox width
                   height="5%",  # height : 50%
                   loc='lower left',
                   bbox_to_anchor=(0, -0.15, 1, 1),
                   bbox_transform=ax2.transAxes,
                   borderpad=0,
                   )

cax4 = inset_axes(ax4,
                   width="230%",  # width = 5% of parent_bbox width
                   height="5%",  # height : 50%
                   loc='lower left',
                   bbox_to_anchor=(0, -0.15, 1, 1),
                   bbox_transform=ax4.transAxes,
                   borderpad=0,
                   )



cax6 = inset_axes(ax6,
                   width="230%",  # width = 5% of parent_bbox width
                   height="5%",  # height : 50%
                   loc='lower left',
                   bbox_to_anchor=(0, -0.15, 1, 1),
                   bbox_transform=ax6.transAxes,
                   borderpad=0,
                   )

plt.subplots_adjust(top=1, bottom=0, left=0, right=1, hspace=0.4
                    ,
                    wspace=0.2) 



levels=np.arange(-1,1.1,0.1)

cmap = plt.cm.RdYlBu_r


p0=plot_regress_map_bf1(ax0,bf1_1,levels=levels,cmap=cmap)
p1=plot_regress_map_bf1(ax1,bf1_2,levels=levels,cmap=cmap)



ax0.set_title('Thin',fontsize=ftz,color='blue')
ax1.set_title('Thick',fontsize=ftz,color='red')



ax0.add_patch(mpatches.Rectangle(xy=[-20, -3], width=20, height=6,edgecolor='blue',fill=None,
                                    alpha=1,linewidth=3,label='ATL3',transform=ccrs.PlateCarree(),zorder=2))



ax1.add_patch(mpatches.Rectangle(xy=[-20, -3], width=20, height=6,edgecolor='blue',fill=None,
                                    alpha=1,linewidth=3,label='ATL3',transform=ccrs.PlateCarree(),zorder=2))


ax0.legend(fontsize=ftz)

cbar = plt.colorbar(p0,cax0,orientation='horizontal')
cbar.ax.tick_params(labelsize=ftz)
cbar.set_label(r'TAUXA response to ATL3 SSTA in OND (10$^{-2}$ N$\cdot$m$^{-2}$$\cdot$$^{\circ}$C$^{-1}$)', size=ftz)






levels2=np.arange(-10,11,1)
cmap2 = plt.cm.RdYlBu_r

p2=plot_regress_map_bf2(ax2,bf2_1,levels=levels2,cmap=cmap2)
p3=plot_regress_map_bf2(ax3,bf2_2,levels=levels2,cmap=cmap2)




ax2.set_title('Thin',fontsize=ftz,color='blue')
ax3.set_title('Thick',fontsize=ftz,color='red')



ax2.add_patch(mpatches.Rectangle(xy=[-40, -3], width=20, height=6,edgecolor='green',fill=None,
                                    alpha=1,linewidth=3,label='ATL4',transform=ccrs.PlateCarree(),zorder=2))



ax3.add_patch(mpatches.Rectangle(xy=[-40, -3], width=20, height=6,edgecolor='green',fill=None,
                                    alpha=1,linewidth=3,label='ATL4',transform=ccrs.PlateCarree(),zorder=2))
ax2.legend(fontsize=ftz)


cbar = plt.colorbar(p2,cax2,orientation='horizontal')
cbar.ax.tick_params(labelsize=ftz)
cbar.set_label(r'ZOSA in OND response to ATL4 TAUXA in SON (m$\cdot$(N$\cdot$m$^{-2}$)$^{-1}$)', size=ftz)




levels4=np.arange(-50,55,5)

cmap = plt.cm.RdYlBu_r

p4=plot_regress_map_bf3(ax4,bf3_1,levels=levels4,cmap=cmap)
p5=plot_regress_map_bf3(ax5,bf3_2,levels=levels4,cmap=cmap)

ax4.set_title('Thin',fontsize=ftz,color='blue')
ax5.set_title('Thick',fontsize=ftz,color='red')



ax4.add_patch(mpatches.Rectangle(xy=[-20, -3], width=20, height=6,edgecolor='blue',fill=None,
                                    alpha=1,linewidth=3,label='ATL3',transform=ccrs.PlateCarree()))
ax4.legend(fontsize=ftz)
ax5.add_patch(mpatches.Rectangle(xy=[-20, -3], width=20, height=6,edgecolor='blue',fill=None,
                                    alpha=1,linewidth=3,label='ATL3',transform=ccrs.PlateCarree()))



cbar = plt.colorbar(p4,cax4,orientation='horizontal')
cbar.ax.tick_params(labelsize=ftz)
cbar.set_label(r'SSTA response to SSHA in OND ($^{\circ}$C$\cdot$m$^{-1}$)', size=ftz)






levels6=np.arange(-50,55,5)

cmap = plt.cm.RdYlBu_r

p6=plot_regress_map_td(ax6,nhfa_ssta_1,levels=levels6,cmap=cmap)
p7=plot_regress_map_td(ax7,nhfa_ssta_2,levels=levels6,cmap=cmap)

ax6.set_title('Thin',fontsize=ftz,color='blue')
ax7.set_title('Thick',fontsize=ftz,color='red')



ax6.add_patch(mpatches.Rectangle(xy=[-20, -3], width=20, height=6,edgecolor='blue',fill=None,
                                    alpha=1,linewidth=3,label='ATL3',transform=ccrs.PlateCarree()))
ax6.legend(fontsize=ftz)
ax7.add_patch(mpatches.Rectangle(xy=[-20, -3], width=20, height=6,edgecolor='blue',fill=None,
                                    alpha=1,linewidth=3,label='ATL3',transform=ccrs.PlateCarree()))



cbar = plt.colorbar(p6,cax6,orientation='horizontal')
cbar.ax.tick_params(labelsize=ftz)
cbar.set_label(r'NHFA response to ATL3 SSTA in OND (W$\cdot$m$^{-2}$$\cdot$$^{\circ}$C$^{-1}$)', size=ftz)





ax0.text(0,
         1.02, 'a)',transform=ax0.transAxes,size=ftz)
ax1.text(0,
         1.02, 'b)',transform=ax1.transAxes,size=ftz)
ax2.text(0,
         1.02, 'c)',transform=ax2.transAxes,size=ftz)
ax3.text(0,
         1.02, 'd)',transform=ax3.transAxes,size=ftz)
ax4.text(0,
         1.02, 'e)',transform=ax4.transAxes,size=ftz)
ax5.text(0,
         1.02, 'f)',transform=ax5.transAxes,size=ftz)
ax6.text(0,
         1.02, 'g)',transform=ax6.transAxes,size=ftz)
ax7.text(0,
         1.02, 'h)',transform=ax7.transAxes,size=ftz)





plt.savefig('figures/figure_BF_TD_atl_OND.png',
             dpi = 300,
            bbox_inches='tight')
# Out:
# /sw/spack-levante/mambaforge-23.1.0-1-Linux-x86_64-3boc6i/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:451: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /sw/spack-levante/mambaforge-23.1.0-1-Linux-x86_64-3boc6i/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:487: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '
# /sw/spack-levante/mambaforge-23.1.0-1-Linux-x86_64-3boc6i/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:451: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /sw/spack-levante/mambaforge-23.1.0-1-Linux-x86_64-3boc6i/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:487: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '
# /sw/spack-levante/mambaforge-23.1.0-1-Linux-x86_64-3boc6i/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:451: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /sw/spack-levante/mambaforge-23.1.0-1-Linux-x86_64-3boc6i/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:487: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '
# /sw/spack-levante/mambaforge-23.1.0-1-Linux-x86_64-3boc6i/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:451: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /sw/spack-levante/mambaforge-23.1.0-1-Linux-x86_64-3boc6i/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:487: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '
# /sw/spack-levante/mambaforge-23.1.0-1-Linux-x86_64-3boc6i/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:451: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /sw/spack-levante/mambaforge-23.1.0-1-Linux-x86_64-3boc6i/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:487: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '
# /sw/spack-levante/mambaforge-23.1.0-1-Linux-x86_64-3boc6i/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:451: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /sw/spack-levante/mambaforge-23.1.0-1-Linux-x86_64-3boc6i/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:487: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '
# /sw/spack-levante/mambaforge-23.1.0-1-Linux-x86_64-3boc6i/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:451: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /sw/spack-levante/mambaforge-23.1.0-1-Linux-x86_64-3boc6i/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:487: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '
# /sw/spack-levante/mambaforge-23.1.0-1-Linux-x86_64-3boc6i/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:451: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /sw/spack-levante/mambaforge-23.1.0-1-Linux-x86_64-3boc6i/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:487: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '

# %%
ftz=15


fig = plt.figure(figsize=[15, 15])
fig.patch.set_facecolor('white')
gs = gridspec.GridSpec(3, 2)



ax0  = fig.add_subplot(gs[0, 0],projection=ccrs.PlateCarree())
ax1  = fig.add_subplot(gs[0, 1],projection=ccrs.PlateCarree())


ax2  = fig.add_subplot(gs[1, 0],projection=ccrs.PlateCarree())
ax3  = fig.add_subplot(gs[1, 1],projection=ccrs.PlateCarree())


ax4  = fig.add_subplot(gs[2, 0],projection=ccrs.PlateCarree())
ax5  = fig.add_subplot(gs[2, 1],projection=ccrs.PlateCarree())




cax0 = inset_axes(ax0,
                   width="220%",  # width = 5% of parent_bbox width
                   height="5%",  # height : 50%
                   loc='lower left',
                   bbox_to_anchor=(0, -0.15, 1, 1),
                   bbox_transform=ax0.transAxes,
                   borderpad=0,
                   )

cax2 = inset_axes(ax2,
                   width="220%",  # width = 5% of parent_bbox width
                   height="5%",  # height : 50%
                   loc='lower left',
                   bbox_to_anchor=(0, -0.15, 1, 1),
                   bbox_transform=ax2.transAxes,
                   borderpad=0,
                   )

cax4 = inset_axes(ax0,
                   width="220%",  # width = 5% of parent_bbox width
                   height="5%",  # height : 50%
                   loc='lower left',
                   bbox_to_anchor=(0, -0.15, 1, 1),
                   bbox_transform=ax4.transAxes,
                   borderpad=0,
                   )

plt.subplots_adjust(top=1, bottom=0, left=0, right=1, hspace=0.4
                    ,
                    wspace=0.1) 



levels=np.arange(-1,1.1,0.1)

cmap = plt.cm.RdYlBu_r


p0=plot_regress_map_bf1(ax0,bf1_1,levels=levels,cmap=cmap)
p1=plot_regress_map_bf1(ax1,bf1_2,levels=levels,cmap=cmap)



ax0.set_title('Thin',fontsize=ftz,color='blue')
ax1.set_title('Thick',fontsize=ftz,color='red')



ax0.add_patch(mpatches.Rectangle(xy=[-20, -3], width=20, height=6,edgecolor='blue',fill=None,
                                    alpha=1,linewidth=3,label='ATL3',transform=ccrs.PlateCarree(),zorder=2))



ax1.add_patch(mpatches.Rectangle(xy=[-20, -3], width=20, height=6,edgecolor='blue',fill=None,
                                    alpha=1,linewidth=3,label='ATL3',transform=ccrs.PlateCarree(),zorder=2))


ax0.legend(fontsize=ftz)

cbar = plt.colorbar(p0,cax0,orientation='horizontal')
cbar.ax.tick_params(labelsize=ftz)
cbar.set_label(r'TAUXA response to ATL3 SSTA in OND (10$^{-2}$ N$\cdot$m$^{-2}$$\cdot$$^{\circ}$C$^{-1}$)', size=ftz)






levels2=np.arange(-10,11,1)
cmap2 = plt.cm.RdYlBu_r

p2=plot_regress_map_bf2(ax2,bf2_1,levels=levels2,cmap=cmap2)
p3=plot_regress_map_bf2(ax3,bf2_2,levels=levels2,cmap=cmap2)




ax2.set_title('Thin',fontsize=ftz,color='blue')
ax3.set_title('Thick',fontsize=ftz,color='red')



ax2.add_patch(mpatches.Rectangle(xy=[-40, -3], width=20, height=6,edgecolor='green',fill=None,
                                    alpha=1,linewidth=3,label='ATL4',transform=ccrs.PlateCarree(),zorder=2))



ax3.add_patch(mpatches.Rectangle(xy=[-40, -3], width=20, height=6,edgecolor='green',fill=None,
                                    alpha=1,linewidth=3,label='ATL4',transform=ccrs.PlateCarree(),zorder=2))
ax2.legend(fontsize=ftz)


cbar = plt.colorbar(p2,cax2,orientation='horizontal')
cbar.ax.tick_params(labelsize=ftz)
cbar.set_label(r'ZOSA in OND response to ATL4 TAUXA in SON (m$\cdot$(N$\cdot$m$^{-2}$)$^{-1}$)', size=ftz)




levels4=np.arange(-50,55,5)

cmap = plt.cm.RdYlBu_r

p4=plot_regress_map_bf3(ax4,bf3_1,levels=levels4,cmap=cmap)
p5=plot_regress_map_bf3(ax5,bf3_2,levels=levels4,cmap=cmap)

ax4.set_title('Thin',fontsize=ftz,color='blue')
ax5.set_title('Thick',fontsize=ftz,color='red')



ax4.add_patch(mpatches.Rectangle(xy=[-20, -3], width=20, height=6,edgecolor='blue',fill=None,
                                    alpha=1,linewidth=3,label='ATL3',transform=ccrs.PlateCarree()))
ax4.legend(fontsize=ftz)
ax5.add_patch(mpatches.Rectangle(xy=[-20, -3], width=20, height=6,edgecolor='blue',fill=None,
                                    alpha=1,linewidth=3,label='ATL3',transform=ccrs.PlateCarree()))



cbar = plt.colorbar(p4,cax4,orientation='horizontal')
cbar.ax.tick_params(labelsize=ftz)
cbar.set_label(r'SSTA response to SSHA in OND ($^{\circ}$C$\cdot$m$^{-1}$)', size=ftz)





ax0.text(0,
         1.02, 'a)',transform=ax0.transAxes,size=ftz)
ax1.text(0,
         1.02, 'b)',transform=ax1.transAxes,size=ftz)
ax2.text(0,
         1.02, 'c)',transform=ax2.transAxes,size=ftz)
ax3.text(0,
         1.02, 'd)',transform=ax3.transAxes,size=ftz)
ax4.text(0,
         1.02, 'e)',transform=ax4.transAxes,size=ftz)
ax5.text(0,
         1.02, 'f)',transform=ax5.transAxes,size=ftz)




plt.savefig('figures/figure_BF_atl_OND.png',
             dpi = 300,
            bbox_inches='tight')
# Out:
# /sw/spack-levante/mambaforge-23.1.0-1-Linux-x86_64-3boc6i/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:451: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /sw/spack-levante/mambaforge-23.1.0-1-Linux-x86_64-3boc6i/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:487: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '
# /sw/spack-levante/mambaforge-23.1.0-1-Linux-x86_64-3boc6i/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:451: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /sw/spack-levante/mambaforge-23.1.0-1-Linux-x86_64-3boc6i/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:487: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '
# /sw/spack-levante/mambaforge-23.1.0-1-Linux-x86_64-3boc6i/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:451: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /sw/spack-levante/mambaforge-23.1.0-1-Linux-x86_64-3boc6i/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:487: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '
# /sw/spack-levante/mambaforge-23.1.0-1-Linux-x86_64-3boc6i/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:451: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /sw/spack-levante/mambaforge-23.1.0-1-Linux-x86_64-3boc6i/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:487: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '
# /sw/spack-levante/mambaforge-23.1.0-1-Linux-x86_64-3boc6i/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:451: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /sw/spack-levante/mambaforge-23.1.0-1-Linux-x86_64-3boc6i/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:487: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '
# /sw/spack-levante/mambaforge-23.1.0-1-Linux-x86_64-3boc6i/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:451: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /sw/spack-levante/mambaforge-23.1.0-1-Linux-x86_64-3boc6i/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:487: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '
